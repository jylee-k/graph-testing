# %%
import networkx as nx

# %%
from cdlib.algorithms import louvain
from cdlib import evaluation
g = nx.karate_club_graph()
communities = louvain(g)
scd = communities.avg_distance()

# %%
print(scd)
# Out:
# FitnessResult(min=1.3333333333333333, max=1.7142857142857142, score=np.float64(1.5073593073593072), std=np.float64(0.15014469885872975))

# %%
from cdlib import algorithms, viz
import networkx as nx
g = nx.karate_club_graph()
coms = algorithms.louvain(g)
position = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, position, show_edge_widths=True)

# %%
viz.plot_network_highlighted_clusters(g, coms, position)
